# %%
# Out:
# ['carro (177).jpg', 'carro (180).jpg', 'carro (1).jpg', 'carro (178).jpg', 'carro (184).jpg', 'carro (181).jpg', 'carro (179).jpg', 'carro (187).jpg', 'carro (185).jpg', 'carro (182).jpg', 'carro (183).jpg', 'carro (186).jpg', 'carro (10).jpg', 'carro (188).jpg', 'carro (189).jpg', 'carro (198).jpg', 'carro (196).jpg', 'carro (195).jpg', 'carro (194).jpg', 'carro (190).jpg', 'carro (197).jpg', 'carro (192).jpg', 'carro (191).jpg', 'carro (193).jpg', 'carro (11).jpg', 'carro (12).jpg', 'carro (13).jpg', 'carro (14).jpg', 'carro (15).jpg', 'carro (16).jpg', 'carro (17).jpg', 'carro (18).jpg', 'carro (19).jpg', 'carro (2).jpg', 'carro (20).jpg', 'carro (21).jpg', 'carro (22).jpg', 'carro (23).jpg', 'carro (24).jpg', 'carro (25).jpg', 'carro (26).jpg', 'carro (27).jpg', 'carro (28).jpg', 'carro (29).jpg', 'carro (3).jpg', 'carro (30).jpg', 'carro (31).jpg', 'carro (32).jpg', 'carro (33).jpg', 'carro (34).jpg', 'carro (35).jpg', 'carro (36).jpg', 'carro (37).jpg', 'carro (38).jpg', 'carro (39).jpg', 'carro (4).jpg', 'carro (40).jpg', 'carro (41).jpg', 'carro (42).jpg', 'carro (43).jpg', 'carro (44).jpg', 'carro (45).jpg', 'carro (46).jpg', 'carro (47).jpg', 'carro (48).jpg', 'carro (49).jpg', 'carro (5).jpg', 'carro (50).jpg', 'carro (51).jpg', 'carro (52).jpg', 'carro (53).jpg', 'carro (54).jpg', 'carro (55).jpg', 'carro (56).jpg', 'carro (57).jpg', 'carro (58).jpg', 'carro (59).jpg', 'carro (6).jpg', 'carro (60).jpg', 'carro (61).jpg', 'carro (62).jpg', 'carro (63).jpg', 'carro (64).jpg', 'carro (65).jpg', 'carro (66).jpg', 'carro (67).jpg', 'carro (68).jpg', 'carro (69).jpg', 'carro (7).jpg', 'carro (70).jpg', 'carro (71).jpg', 'carro (72).jpg', 'carro (73).jpg', 'carro (74).jpg', 'carro (75).jpg', 'carro (76).jpg', 'carro (77).jpg', 'carro (78).jpg', 'carro (79).jpg', 'carro (8).jpg', 'carro (80).jpg', 'carro (81).jpg', 'carro (82).jpg', 'carro (83).jpg', 'carro (84).jpg', 'carro (9).jpg']

# %%
from PIL import Image

# Ruta de una imagen específica (ejemplo con la primera imagen de la lista)
image_path = os.path.join(folder_path, image_files[0])

# Cargar y mostrar la imagen
image = Image.open(image_path)
image.show()

# %%
import cv2
from matplotlib import pyplot as plt

# Ruta de una imagen específica
image_path = os.path.join(folder_path, image_files[0])

# Cargar y mostrar la imagen
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB
plt.imshow(image)
plt.show()
